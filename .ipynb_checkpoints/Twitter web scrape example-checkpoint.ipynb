# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_json('/Users/ryan/text-query-tweets.json', lines=True)

# %%
elephant_df = df.loc[df['renderedContent'].str.contains('elephant') == True]

# %%
elephant_tweets = []
for tweet in elephant_df['renderedContent']:
    elephant_tweets.append(tweet)

# %%
for tweet in elephant_tweets:
    print(tweet)
    print()
# Out:
# @SiBuduh @langoinstitute do you know the Ko word for ‘elephant’ and its derivation? one of the 1st instances I saw of this phenomenon in Ko
#
# @RockstarGames Any idea if the elephant rifle is bugged? I shoot a 3 star animal and when I go collect its pelt it's a 1 star. Doesnt this defeat the purpose of this weapon if it's designed for hunting animal's. Hope this gets fixed or tuned in a hotfix.
#
# @realDonaldTrump Trump just keeps ignoring the elephant in the room. Americans 1st concern is Covid-19 pandemic that has re surged in US &amp; killed 150k. Trump tried denying it, ignoring it &amp; bullying it but the virus just keeps doing its deadly thing. BYE DON
#
# @cslogan88 Famous 19th century song from England- (its about an elephant but, you know..)- "Nelly the Elephant packed his Trunk and said goodbye to the circus, of he went with a Trumpety Trump, Trump, Trump, Trump.....".... check youtube, worth a re- "lyricing" shall we say :)
#
# ...

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
labels = ['Contains Elephants', "Doesn't contain elephants"]
count_tweets = [len(elephant_tweets), (500 - len(elephant_tweets))]
ax.bar(labels,count_tweets)
plt.show()
